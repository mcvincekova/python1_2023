# %% [markdown]
# # `pandas`: Propojení dat
# Odkaz na lekci: https://kodim.cz/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/propojeni-dat

# %%
import pandas

# %% [markdown]
# ### Načtení dat
#
# Data, se kterými budeme pracovat, si můžeš stáhnout zde:
# * [studenti.csv](https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/studenti.csv)
# * [predsedajici.csv](https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/predsedajici.csv)

# %%
studenti = pandas.read_csv("../data/studenti.csv")
studenti.head()
# studenti.info()
# Out:
#    cisloStudenta             jmeno
# 0              1    Jana Zbořilová
# 1              2      Lukáš Jurčík
# 2              3       Pavel Horák
# 3              4     Pavel Kysilka
# 4              5  Kateřina Novotná

# %%
predsedajici = pandas.read_csv("../data/predsedajici.csv")
predsedajici.head()
# predsedajici.info()
# Out:
#        datum             jmeno  den
# 0  20.5.2019  Marie Zuzaňáková  po
# 1  21.5.2019  Marie Zuzaňáková   út
# 2  22.5.2019     Petr Ortinský   st
# 3  23.5.2019     Petr Ortinský   čt
# 4  24.5.2019   Alena Pniáčková   pá

# %% [markdown]
# Také budeme potřebovat tabulku `maturita.csv`, kterou jsme si vytvořili minulou lekci. Pokud jí nemáš po ruce, stáhni si jí zde: [maturita.csv](https://raw.githubusercontent.com/lutydlitatova/python-jaro-2023/main/notebook/maturita.csv)

# %%
maturita = pandas.read_csv("../data/maturita.csv")
maturita.head()
# maturita.info()
# Out:
#    cisloStudenta           predmet  znamka den mistnost
# 0              2           Dějepis     3.0  pá     u202
# 1              3        Matematika     2.0  út     u202
# 2              2  Společenské vědy     2.0  pá     u202
# 3              4          Biologie     1.0  pá     u202
# 4              5           Dějepis     1.0  po     u202

# %% [markdown]
# ### Propojení dat pomocí `merge`
# Jak `pandas` pozná, podle kterých sloupců data propojit? Jak můžeme sloupce, podle kterých chceme data propojit, specifikovat?

# %%
maturita_se_studenty = pandas.merge(maturita, studenti)
maturita_se_studenty
# Out:
#     cisloStudenta           predmet  znamka den mistnost              jmeno
# 0               2           Dějepis     3.0  pá     u202       Lukáš Jurčík
# 1               2  Společenské vědy     2.0  pá     u202       Lukáš Jurčík
# 2               3        Matematika     2.0  út     u202        Pavel Horák
# 3               3            Chemie     5.0  út     u202        Pavel Horák
# 4               4          Biologie     1.0  pá     u202      Pavel Kysilka
# 5               4       Informatika     1.0  pá     u302      Pavel Kysilka
# 6               5           Dějepis     1.0  po     u202   Kateřina Novotná
# 7               5  Společenské vědy     3.0  po     u203   Kateřina Novotná
# 8               6            Fyzika     2.0  čt     u202  Marie Krejcárková
# 9               6        Matematika     5.0  čt     u302  Marie Krejcárková
# 10              7           Dějepis     4.0  po     u202        Vasil Lácha
# 11              7       Informatika     3.0  po     u203        Vasil Lácha
# 12              8        Matematika     2.0  po     u202     Alexey Opatrný
# 13              8           Zeměpis     1.0  po     u203     Alexey Opatrný
# 14             10            Chemie     2.0  st     u202    Miroslav Bednář
# 15             10           Dějepis     5.0  st     u202    Miroslav Bednář
# 16             11        Matematika     1.0  st     u202    Ivana Dvořáková
# 17             11            Chemie     5.0  st     u302    Ivana Dvořáková
# 18             12          Biologie     4.0  st     u202     Lenka Jarošová
# 19             12            Fyzika     3.0  st     u203     Lenka Jarošová
# 20             13        Matematika     5.0  po     u203         Arnošt Sas
# 21             13            Chemie     4.0  po     u302         Arnošt Sas
# 22             14            Fyzika     3.0  st     u203    Marie Kortusová
# 23             14           Dějepis     3.0  st     u302    Marie Kortusová
# 24             15            Chemie     3.0  pá     u203    Monika Dudysová
# 25             15  Společenské vědy     3.0  pá     u203    Monika Dudysová
# 26             16       Informatika     2.0  út     u203   Josef Vodseďálek
# 27             16          Biologie     2.0  út     u302   Josef Vodseďálek
# 28             17            Fyzika     4.0  po     u203     Antonín Hlídek
# 29             17        Matematika     3.0  po     u302     Antonín Hlídek
# 30             20            Fyzika     2.0  čt     u203     Marta Kinclová
# 31             20        Matematika     1.0  čt     u302     Marta Kinclová
# 32             21          Biologie     4.0  st     u203  Martina Korbářová
# 33             21       Informatika     4.0  st     u302  Martina Korbářová
# 34             22           Zeměpis     3.0  út     u203         Petr Tábor
# 35             22       Informatika     3.0  út     u302         Petr Tábor

# %% [markdown]
# Propojení dat o maturitě s daty o předsedajících se nepovede. Proč? Na základě kterého sloupce nebo kterých sloupců chceme data propojit? Budeme také muset vyřešit záhadu poztrácených dat.

# %%
maturita_s_predsedajicimi = pandas.merge(maturita_se_studenty, predsedajici, on=['den'])
maturita_s_predsedajicimi
# Out:
#     cisloStudenta           predmet  znamka den mistnost            jmeno_x  \
# 0               2           Dějepis     3.0  pá     u202       Lukáš Jurčík
# 1               2  Společenské vědy     2.0  pá     u202       Lukáš Jurčík
# 2               4          Biologie     1.0  pá     u202      Pavel Kysilka
# 3               4       Informatika     1.0  pá     u302      Pavel Kysilka
# 4              15            Chemie     3.0  pá     u203    Monika Dudysová
# 5              15  Společenské vědy     3.0  pá     u203    Monika Dudysová
# 6               3        Matematika     2.0  út     u202        Pavel Horák
# 7               3            Chemie     5.0  út     u202        Pavel Horák
# 8              16       Informatika     2.0  út     u203   Josef Vodseďálek
# 9              16          Biologie     2.0  út     u302   Josef Vodseďálek
# 10             22           Zeměpis     3.0  út     u203         Petr Tábor
# 11             22       Informatika     3.0  út     u302         Petr Tábor
# 12              6            Fyzika     2.0  čt     u202  Marie Krejcárková
# 13              6        Matematika     5.0  čt     u302  Marie Krejcárková
# 14             20            Fyzika     2.0  čt     u203     Marta Kinclová
# 15             20        Matematika     1.0  čt     u302     Marta Kinclová
# 16             10            Chemie     2.0  st     u202    Miroslav Bednář
# 17             10           Dějepis     5.0  st     u202    Miroslav Bednář
# 18             11        Matematika     1.0  st     u202    Ivana Dvořáková
# 19             11            Chemie     5.0  st     u302    Ivana Dvořáková
# 20             12          Biologie     4.0  st     u202     Lenka Jarošová
# 21             12            Fyzika     3.0  st     u203     Lenka Jarošová
# 22             14            Fyzika     3.0  st     u203    Marie Kortusová
# 23             14           Dějepis     3.0  st     u302    Marie Kortusová
# 24             21          Biologie     4.0  st     u203  Martina Korbářová
# 25             21       Informatika     4.0  st     u302  Martina Korbářová
#
#         datum           jmeno_y
# 0   24.5.2019   Alena Pniáčková
# 1   24.5.2019   Alena Pniáčková
# 2   24.5.2019   Alena Pniáčková
# 3   24.5.2019   Alena Pniáčková
# 4   24.5.2019   Alena Pniáčková
# 5   24.5.2019   Alena Pniáčková
# 6   21.5.2019  Marie Zuzaňáková
# 7   21.5.2019  Marie Zuzaňáková
# 8   21.5.2019  Marie Zuzaňáková
# 9   21.5.2019  Marie Zuzaňáková
# 10  21.5.2019  Marie Zuzaňáková
# 11  21.5.2019  Marie Zuzaňáková
# 12  23.5.2019     Petr Ortinský
# 13  23.5.2019     Petr Ortinský
# 14  23.5.2019     Petr Ortinský
# 15  23.5.2019     Petr Ortinský
# 16  22.5.2019     Petr Ortinský
# 17  22.5.2019     Petr Ortinský
# 18  22.5.2019     Petr Ortinský
# 19  22.5.2019     Petr Ortinský
# 20  22.5.2019     Petr Ortinský
# 21  22.5.2019     Petr Ortinský
# 22  22.5.2019     Petr Ortinský
# 23  22.5.2019     Petr Ortinský
# 24  22.5.2019     Petr Ortinský
# 25  22.5.2019     Petr Ortinský

# %% [markdown]
# # `pandas`: Agregace dat
# Odkaz na lekci: https://kodim.cz/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/agregace

# %%
maturita_s_predsedajicimi.groupby("predmet")

# %%
maturita_s_predsedajicimi.groupby("predmet")["znamka"]

# %%
maturita_s_predsedajicimi.groupby("predmet")["znamka"].mean()
# Out:
# predmet
# Biologie            2.750000
# Chemie              3.750000
# Dějepis             3.666667
# Fyzika              2.500000
# Informatika         2.500000
# Matematika          2.250000
# Společenské vědy    2.500000
# Zeměpis             3.000000
# Name: znamka, dtype: float64

# %%
maturita_s_predsedajicimi.groupby("predmet")["znamka"].max()
# Out:
# predmet
# Biologie            4.0
# Chemie              5.0
# Dějepis             5.0
# Fyzika              3.0
# Informatika         4.0
# Matematika          5.0
# Společenské vědy    3.0
# Zeměpis             3.0
# Name: znamka, dtype: float64

# %% [markdown]
# `size` vs `count`
# * https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.GroupBy.size.html
# * https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.GroupBy.count.html

# %%
maturita_s_predsedajicimi.groupby("predmet").count()
# Out:
#                   cisloStudenta  znamka  den  mistnost  jmeno_x  datum  \
# predmet
# Biologie                      4       4    4         4        4      4
# Chemie                        4       4    4         4        4      4
# Dějepis                       3       3    3         3        3      3
# Fyzika                        4       4    4         4        4      4
# Informatika                   4       4    4         4        4      4
# Matematika                    4       4    4         4        4      4
# Společenské vědy              2       2    2         2        2      2
# Zeměpis                       1       1    1         1        1      1
#
#                   jmeno_y
# predmet
# Biologie                4
# Chemie                  4
# Dějepis                 3
# Fyzika                  4
# Informatika             4
# Matematika              4
# Společenské vědy        2
# Zeměpis                 1

# %%
maturita_s_predsedajicimi.groupby("predmet").size()
# Out:
# predmet
# Biologie            4
# Chemie              4
# Dějepis             3
# Fyzika              4
# Informatika         4
# Matematika          4
# Společenské vědy    2
# Zeměpis             1
# dtype: int64
